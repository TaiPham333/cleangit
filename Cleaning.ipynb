# %%
import pandas as pd
df = pd.read_csv('E:/Skills/Data Cleaning and Manipulate/CLEANING(BUSA8000)R/Lecture/Week 3 Lecture Data-20210711/2018_19_GT_Results.csv')

# %%
import numpy as np

# %%
df.sample(5)
# Out:
#     Timestamp Entering Grade Level  District Birth Month  OLSAT Verbal Score  \
# 7     3/27/18                    1      28.0   September                27.0
# 15  3/27/2018                    K      15.0     January                28.0
# 1     3/27/18                    1       2.0    November                25.0
# 35    3/27/18                    K       2.0       March                29.0
# 3   3/27/2018                    1       2.0    December                27.0
#
#     OLSAT Verbal Percentile  NNAT Non Verbal Raw Score  \
# 7                      98.0                       42.0
# 15                     99.0                       36.0
# 1                      99.0                       40.0
# 35                     99.0                       43.0
# 3                      99.0                       41.0
#
#     NNAT Non Verbal Percentile  Overall Score               Unnamed: 9  \
# 7                         99.0             99                      NaN
# ...

# %%
missing_values_count=df.isnull().sum()
missing_values_count
# Out:
# Timestamp                      0
# Entering Grade Level           0
# District                       1
# Birth Month                    0
# OLSAT Verbal Score             1
# OLSAT Verbal Percentile        2
# NNAT Non Verbal Raw Score      1
# NNAT Non Verbal Percentile     1
# Overall Score                  0
# Unnamed: 9                    11
# Unnamed: 10                   46
# School Assigned               46
# Will you enroll there?        31
# Test Prep?                    19
# Unnamed: 14                   44
# dtype: int64

# %%
total_rows=np.product(df.shape)
total_miss=missing_values_count.sum()

(total_miss/total_rows)*100
# Out:
# 29.42028985507246

# %%
df.dropna()#see no rows
# Out:
# Empty DataFrame
# Columns: [Timestamp, Entering Grade Level, District, Birth Month, OLSAT Verbal Score, OLSAT Verbal Percentile, NNAT Non Verbal Raw Score, NNAT Non Verbal Percentile, Overall Score, Unnamed: 9, Unnamed: 10, School Assigned, Will you enroll there?, Test Prep?, Unnamed: 14]
# Index: []

# %%
df.dropna(axis=1).head(5)
# Out:
#    Timestamp Entering Grade Level Birth Month  Overall Score
# 0    3/27/18                    1    November             99
# 1    3/27/18                    1    November             99
# 2    3/27/18                    1      August             99
# 3  3/27/2018                    1    December             99
# 4  3/27/2018                    1        July             99

# %%
df.fillna(0).head(5)
# Out:
#    Timestamp Entering Grade Level  District Birth Month  OLSAT Verbal Score  \
# 0    3/27/18                    1       2.0    November                25.0
# 1    3/27/18                    1       2.0    November                25.0
# 2    3/27/18                    1       2.0      August                27.0
# 3  3/27/2018                    1       2.0    December                27.0
# 4  3/27/2018                    1       2.0        July                28.0
#
#    OLSAT Verbal Percentile  NNAT Non Verbal Raw Score  \
# 0                     99.0                       40.0
# 1                     99.0                       40.0
# 2                     98.0                       42.0
# 3                     99.0                       41.0
# 4                     99.0                       43.0
#
#    NNAT Non Verbal Percentile  Overall Score               Unnamed: 9  \
# 0                        99.0             99                   NEST+M
# ...

# %%
df.fillna(method='bfill',axis=0).fillna(0)
# Out:
#     Timestamp Entering Grade Level  District Birth Month  OLSAT Verbal Score  \
# 0     3/27/18                    1       2.0    November                25.0
# 1     3/27/18                    1       2.0    November                25.0
# 2     3/27/18                    1       2.0      August                27.0
# 3   3/27/2018                    1       2.0    December                27.0
# 4   3/27/2018                    1       2.0        July                28.0
# 5   3/27/2018                    1       2.0       March                28.0
# 6     3/27/18                    1       3.0     January                28.0
# 7     3/27/18                    1      28.0   September                27.0
# 8   3/27/2018                    1      30.0     January                30.0
# 9   3/27/2017                    2       2.0      August                30.0
# 10    3/27/18                    K      35.0   September                23.0
# ...

# %%
df.drop(['Timestamp','District'],axis=1)#inplace = true
# Out:
#    Entering Grade Level Birth Month  OLSAT Verbal Score  \
# 0                     1    November                25.0
# 1                     1    November                25.0
# 2                     1      August                27.0
# 3                     1    December                27.0
# 4                     1        July                28.0
# 5                     1       March                 NaN
# 6                     1     January                28.0
# 7                     1   September                27.0
# 8                     1     January                30.0
# 9                     2      August                30.0
# 10                    K   September                23.0
# 11                    K        June                29.0
# 12                    K       April                20.0
# 13                    K    October                 26.0
# 14                    K        June                27.0
# 15                    K     January                28.0
# ...

# %%
def percen (x):
    if x<=100 and x>=98:
        return 'A'
    elif x>95 and x<98:
        return 'B'
    else:
        return 'C'

# %%
df['percentile']=df['OLSAT Verbal Percentile'].apply(percen)

# %%
df['percentile']
# Out:
# 0     A
# 1     A
# 2     A
# 3     A
# 4     A
# 5     C
# 6     A
# 7     A
# 8     A
# 9     A
# 10    A
# 11    A
# 12    C
# 13    A
# 14    A
# 15    A
# 16    A
# 17    C
# 18    C
# 19    A
# 20    A
# 21    C
# 22    C
# 23    C
# 24    A
# 25    A
# 26    A
# 27    C
# 28    C
# 29    C
# 30    B
# 31    C
# 32    C
# 33    C
# 34    A
# 35    A
# 36    C
# 37    C
# 38    A
# 39    B
# 40    B
# 41    C
# 42    B
# 43    C
# 44    C
# 45    C
# Name: percentile, dtype: object

# %%
df['percentile']=df['OLSAT Verbal Percentile'].apply(lambda x: 'A' if (x<=100 and x >= 98) else ('B' if x > 95 and x<98 else 'c'))

# %%
df['percentile'].head(6)
# Out:
# 0    A
# 1    A
# 2    A
# 3    A
# 4    A
# 5    c
# Name: percentile, dtype: object

# %%
df['Timestamp'].unique()
# Out:
# array(['3/27/18', '3/27/2018', '3/27/2017', 'Mar-27', 'Mar-18',
#        '3/28/2018'], dtype=object)

# %%
df['Timestamp']=df['Timestamp'].replace({'3/27/18':'3/27/2018', 'Mar-27':'3/27/2018','Mar-18':'18/3/2018','3/27/2017':'3/27/2018'})
df['Timestamp'].unique()
# Out:
# array(['3/27/2018', '18/3/2018', '3/28/2018'], dtype=object)

# %%
df=df.rename({'Timestamp':'Time'},axis='columns')
df
# Out:
#          Time Entering Grade Level  District Birth Month  OLSAT Verbal Score  \
# 0   3/27/2018                    1       2.0    November                25.0
# 1   3/27/2018                    1       2.0    November                25.0
# 2   3/27/2018                    1       2.0      August                27.0
# 3   3/27/2018                    1       2.0    December                27.0
# 4   3/27/2018                    1       2.0        July                28.0
# 5   3/27/2018                    1       2.0       March                 NaN
# 6   3/27/2018                    1       3.0     January                28.0
# 7   3/27/2018                    1      28.0   September                27.0
# 8   3/27/2018                    1      30.0     January                30.0
# 9   3/27/2018                    2       2.0      August                30.0
# 10  3/27/2018                    K      35.0   September                23.0
# ...

# %%
df_clean=df['OLSAT Verbal Score'].dropna()

# %%
df['OLSAT Verbal Score']=df['OLSAT Verbal Score'].fillna(df['OLSAT Verbal Score'].mean())
df['OLSAT Verbal Score']
# Out:
# 0     25.000000
# 1     25.000000
# 2     27.000000
# 3     27.000000
# 4     28.000000
# 5     24.622222
# 6     28.000000
# 7     27.000000
# 8     30.000000
# 9     30.000000
# 10    23.000000
# 11    29.000000
# 12    20.000000
# 13    26.000000
# 14    27.000000
# 15    28.000000
# 16    25.000000
# 17    23.000000
# 18    22.000000
# 19    25.000000
# 20    24.000000
# 21    20.000000
# 22    26.000000
# 23    22.000000
# 24    23.000000
# 25    25.000000
# 26    25.000000
# 27    25.000000
# 28    25.000000
# 29    27.000000
# 30    26.000000
# 31    24.000000
# 32    23.000000
# 33    24.000000
# 34    26.000000
# 35    29.000000
# 36    24.000000
# 37    24.000000
# 38    29.000000
# 39    22.000000
# 40    24.000000
# 41    24.000000
# 42    20.000000
# 43    18.000000
# 44    15.000000
# 45    19.000000
# Name: OLSAT Verbal Score, dtype: float64

# %%
df['Birth Month'].unique()
# Out:
# array(['November', 'August', 'December', 'July', 'March', 'January',
#        'September', 'June', 'April', 'October ', 'May', 'February',
#        'Febrauary', 'september'], dtype=object)

# %%
df['Birth Month']=df['Birth Month'].replace({'Febrauary':'February','september':'September'})
df['Birth Month'].unique()
# Out:
# array(['November', 'August', 'December', 'July', 'March', 'January',
#        'September', 'June', 'April', 'October ', 'May', 'February'],
#       dtype=object)

# %%
df['Entering Grade Level']=df['Entering Grade Level'].replace({'K':0})
type(df['Entering Grade Level'][0])
# Out:
# str

# %%
df['Entering Grade Level']=pd.to_numeric(df['Entering Grade Level'])
type(df['Entering Grade Level'][0])
# Out:
# numpy.int64

# %%
df['Entry Grade']=df['Entering Grade Level'].astype('category')
type(df['Entry Grade'][0])
# Out:
# numpy.int64

# %%
df.dropna(axis=1)
# Out:
#     Timestamp Entering Grade Level Birth Month  Overall Score percentile
# 0     3/27/18                    1    November             99          A
# 1     3/27/18                    1    November             99          A
# 2     3/27/18                    1      August             99          A
# 3   3/27/2018                    1    December             99          A
# 4   3/27/2018                    1        July             99          A
# 5   3/27/2018                    1       March             99          C
# 6     3/27/18                    1     January             99          A
# 7     3/27/18                    1   September             99          A
# 8   3/27/2018                    1     January             99          A
# 9   3/27/2017                    2      August             99          A
# 10    3/27/18                    K   September             99          A
# 11  3/27/2018                    K        June             99          A
# ...
